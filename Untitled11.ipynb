# %% [markdown]
# <a href="https://colab.research.google.com/github/BlazeAxel99/DS-CB/blob/main/Untitled11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([1,2,3,4,5])
y = x**2 + 3

# %%
print(x,y)
# Out:
# [1 2 3 4 5] [ 4  7 12 19 28]

# %%
plt.style.use('seaborn')

# %%
plt.plot(x,y)
plt.title("My line plot")
# Out:
# Text(0.5, 1.0, 'My line plot')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.scatter(x,y)

# %% [markdown]
# # working with open cv

# %%
import cv2

# %%
img = cv2.imread('/content/Pokémon_Bulbasaur_art.png')

# %%
img1 = cv2.imread('/content/dc75b96b4141c0a0f5d2658b084e170b.png')

# %%
img2 =cv2.imread('/content/pikachu_hi_pokemon.jpg')

# %% [markdown]
# open cv read img as BGR format

# %%
plt.imshow(img)
rgb_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
crop_img= rgb_img[50:200,0:150,:]
plt.imshow(crop_img)

# %%
plt.imshow(rgb_img)

# %%
plt.imshow(rgb_img)
plt.axis("off")
# Out:
# (-0.5, 274.5, 255.5, -0.5)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)
