# %% [markdown]
# <a href="https://colab.research.google.com/github/BlazeAxel99/DS-CB/blob/main/oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
print(isinstance(a,object))

# %%
a = print
print(isinstance(a,object))

# %%
a = 'kash'
print(isinstance(a,object))

# %%
class A:
  pass

# %%
a=A()
print(isinstance(a,object))

# %%
class person:
  pass

p = person()
print(p)

# %%
hex(id(p))

# %% [markdown]
# Class with a method

# %%
class person:
  def say_hi(self):
    self.name='kash'
    print('hello how are you '+ self.name + "?")

p=person()
p.say_hi()

# %% [markdown]
# The **________init ________ **  method

# %%
class Person:
   name= "kash"
   def say_hi(self):
    print('hello my name is',self.name)

p = Person()
p.say_hi()

Person.say_hi(p)

# %%
class Person:
   name='kash'
  #not a constructor
   def __init__(self):
     print('new object created')
     pass
   def say_hi(self):
    print('hello my name is',self.name)

p = Person()
p.say_hi()

Person.say_hi(p)

# %% [markdown]
# Dunder or magic methods

# %%
class car:
  def __init__(self,model,mileage):
    self.model=model
    self.mileage=mileage
  
  def __str__(self):
    return "{} {}".format(self.model,self.mileage)

  def __repr__(self):
    return "{}".format(self.model)

  def __eq__(self,other):
    return self.mileage == other.mileage

  def __add__(self,other):
    return self.mileage + other.mileage

# %%
c1 = car('a',2)
c2 = car('b',2)

# %%
c1 + c2

# %%
c1 == c2

# %%
#cout<<"kash"

# %%
class ostream:
   def __lshift__(self,other):

      print(other,end = ' ')
      return self
      
cout = ostream()

# %%
cout << "kash" <<"moulik"

# %%
class Dog:

    tricks = set()          # mistaken use of a class variable

    def __init__(self, name):
        self.name = name

    def add_trick(self, trick):
        self.tricks.add(trick)

# %%
a= Dog('bruno')

# %%
b= Dog('maxx')

# %%
a.add_trick('talk')

# %%
a.add_trick('fetch')

# %%
a.tricks

# %%
b.tricks

# %%
id(a.tricks)

# %%
id(b.tricks)

# %% [markdown]
# soln for above issue

# %%
class Dog:

   # tricks = set()          # mistaken use of a class variable

    def __init__(self, name):
        self.name = name
        self.tricks = []
    def add_trick(self, trick):
        self.tricks.append(trick)

# %%
a= Dog('bruno')

# %%
b= Dog('maxx')

# %%
a.add_trick('talk')

# %%
a.add_trick('fetch')

# %%
a.tricks

# %%
b.tricks

# %% [markdown]
# Inheritance
#
# One of the major benefits of object oriented programming is reuse of code and one of the ways this is achieved is through the inheritance mechanism. Inheritance can be best imagined as implementing a type and subtype relationship between classes.

# %%
class SchoolMember:
    '''Represents any school member.'''
    def __init__(self, name, age):
        self.name = name
        self.age = age
        print('(Initialized SchoolMember: {})'.format(self.name))
        self.base()

    def tell(self):
        '''Tell my details.'''
        print('Name:"{}" Age:"{}"'.format(self.name, self.age), end=" ")
        
    def base(self):
        print("heya !")

class Teacher(SchoolMember):
    '''Represents a teacher.'''
    def __init__(self, name, age, salary):
        super().__init__(name,age) #we use super in place of SchoolMember.__init__(self, name, age)
#         self.name = name
#         self.age = age
        self.salary = salary
        print('(Initialized Teacher: {})'.format(self.name))
        self.base()

    def tell(self):
        SchoolMember.tell(self)
        print('Salary: "{:d}"'.format(self.salary))
        
        
class Student(SchoolMember):
    '''Represents a student.'''
    def __init__(self, name, age, marks):
        super().__init__( name, age)
        self.marks = marks
        print('(Initialized Student: {})'.format(self.name))

    def tell(self):
        super().tell()
        print('Marks: "{:d}"'.format(self.marks))

        
t = Teacher('Mr. Ujjwal', 40, 30000)
t.tell()
s = Student('Nikhil', 25, 75)
s.tell()

# %% [markdown]
# ![Screenshot 2021-02-05 204843.png](data:image/png;base64,...)

# %%
class A:
    x=10
class B(A):
    pass
class C(A):
    x=5
class D(C):
    pass

class E( B, D):
   pass

# %%
E.__mro__

# %%
class A:
    x=10
class B(A):
    pass
class C(A):
    pass
class D(C):
    x=5

class E( B, D):
   pass

# %%
E.x

# %%
#above is done by C3 Linearisation
